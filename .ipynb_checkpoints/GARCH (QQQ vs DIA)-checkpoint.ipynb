# %%
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_pacf
from arch import arch_model
from download import download

apikey = open("apikey", "r").readline()

# %%
QQQ = download("QQQ", apikey).rename(columns={"adjClose": "QQQ"}) # NASDAQ Index (Growth)
DIA = download("DIA", apikey).rename(columns={"adjClose": "DIA"}) # Dow Index (Value)

dat = QQQ.merge(DIA, on="date")
print(dat)
# Out:
#             date         QQQ     DIA
# 0     2000-01-03   81.233757   67.59
# 1     2000-01-04   75.660973   65.36
# 2     2000-01-05   73.731964   66.21
# 3     2000-01-06   68.668221   66.55
# 4     2000-01-07   77.161346   68.78
# ...          ...         ...     ...
# 5943  2023-08-17  358.580000  344.55
# 5944  2023-08-18  358.130000  345.12
# 5945  2023-08-21  363.900000  344.67
# 5946  2023-08-22  363.380000  342.96
# 5947  2023-08-23  369.110000  344.83
#
# [5948 rows x 3 columns]

# %%
t0 = np.array(dat["QQQ"][0:-1])
t1 = np.array(dat["QQQ"][1:])
QQQ = (t1 - t0) * 100 / t0

t0 = np.array(dat["DIA"][0:-1])
t1 = np.array(dat["DIA"][1:])
DIA = (t1 - t0) * 100 / t0

plt.plot(QQQ, label="QQQ", color="steelblue")
plt.plot(DIA, label="DIA", color="cadetblue")
plt.legend()
plt.show()

# %%
res = QQQ - DIA
plt.plot(res, label="QQQ - DIA", color="steelblue")
plt.legend()
plt.show()

# %%
plot_pacf(res**2)
plt.show()

# %%
lags = 2
model = arch_model(res, p=lags, q=lags)

# %%
model.fit().summary()
# Out:
# Iteration:      1,   Func. Count:      8,   Neg. LLF: 12151162950.771782
# Iteration:      2,   Func. Count:     20,   Neg. LLF: 3213283126.1823554
# Iteration:      3,   Func. Count:     29,   Neg. LLF: 36230703.68560229
# Iteration:      4,   Func. Count:     37,   Neg. LLF: 6944.033901766557
# Iteration:      5,   Func. Count:     45,   Neg. LLF: 13666.615636710745
# Iteration:      6,   Func. Count:     53,   Neg. LLF: 6950.642405657463
# Iteration:      7,   Func. Count:     61,   Neg. LLF: 6919.525372000882
# Iteration:      8,   Func. Count:     69,   Neg. LLF: 6843.340377440769
# Iteration:      9,   Func. Count:     77,   Neg. LLF: 6882.832624659126
# Iteration:     10,   Func. Count:     85,   Neg. LLF: 6900.776019124652
# Iteration:     11,   Func. Count:     93,   Neg. LLF: 6844.284531642088
# Iteration:     12,   Func. Count:    101,   Neg. LLF: 6812.582061651807
# Iteration:     13,   Func. Count:    108,   Neg. LLF: 6880.771239781556
# Iteration:     14,   Func. Count:    116,   Neg. LLF: 6937.086702081318
# Iteration:     15,   Func. Count:    125,   Neg. LLF: 6812.171939519789
# Iteration:     16,   Func. Count:    133,   Neg. LLF: 6812.122774769061
# Iteration:     17,   Func. Count:    141,   Neg. LLF: 6812.120230008983
# Iteration:     18,   Func. Count:    147,   Neg. LLF: 6812.120230009556
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6812.120230008983
#             Iterations: 18
#             Function evaluations: 147
#             Gradient evaluations: 18
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                      Constant Mean - GARCH Model Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                      GARCH   Log-Likelihood:               -6812.12
# Distribution:                  Normal   AIC:                           13636.2
# Method:            Maximum Likelihood   BIC:                           13676.4
#                                         No. Observations:                 5947
# Date:                Wed, Aug 23 2023   Df Residuals:                     5946
# Time:                        20:09:52   Df Model:                            1
#                                  Mean Model
# ============================================================================
#                  coef    std err          t      P>|t|      95.0% Conf. Int.
# ----------------------------------------------------------------------------
# mu             0.0273  8.619e-03      3.170  1.524e-03 [1.043e-02,4.422e-02]
#                                Volatility Model
# =============================================================================
#                  coef    std err          t      P>|t|       95.0% Conf. Int.
# -----------------------------------------------------------------------------
# omega      5.9341e-03  1.876e-03      3.163  1.561e-03  [2.257e-03,9.611e-03]
# alpha[1]       0.0995  1.620e-02      6.145  7.980e-10    [6.780e-02,  0.131]
# alpha[2]   7.5599e-17  1.695e-02  4.461e-15      1.000 [-3.321e-02,3.321e-02]
# beta[1]        0.2267  6.673e-02      3.397  6.809e-04    [9.591e-02,  0.358]
# beta[2]        0.6654  5.765e-02     11.543  8.052e-31      [  0.552,  0.778]
# =============================================================================
#
# Covariance estimator: robust
# """

# %%
pred = []
start = res.shape[0] - 1000
for i in range(start, res.shape[0]):
    test = res[:i]
    model = arch_model(test, p=lags, q=lags)
    yhat = np.sqrt(model.fit(disp="off").forecast(horizon=1).variance.values[-1,:][0])
    pred.append(yhat)

# %%
plt.figure(figsize=(15,5))
plt.plot(res[start:])
plt.plot(pred, color="red")
plt.show()

# %%
model = arch_model(res, p=lags, q=lags)
yhat = np.sqrt(model.fit(disp="off").forecast(horizon=5).variance.values[-1,:])
plt.plot(yhat)
plt.show()
